# %%
#para el filtro de 8 um:

import numpy as np
import matplotlib.pyplot as plt

energia = np.array([9, 9.5, 10, 10.5, 11, 11.5, 12, 12.5, 13])
z_max = np.array([-0.499, 0.195, 0.183, 0.1709, 0.157, 0.143, 0.131, 0.115, 0.101])  
dosis_max = np.array([0, 2.8712e-08, 2.8035e-08, 2.6246e-08, 2.6565e-08, 2.4904e-08, 2.4038e-08, 2.395e-08, 2.3551e-08])

plt.axhspan(0.115, 0.315, color='r', alpha=0.2, label='pouch')
plt.axhspan(-0.115, 0.115, color='g', alpha=0.2, label='acrilico')
plt.plot(energia, z_max, 'o-', color='blue', label='Simulación')

plt.xlabel('Energía del haz (MeV)')
plt.ylabel('Posición del pico de Bragg z_max (cm)')
plt.title('z_max vs Energía del haz')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
